# %% [markdown]
# ## ✅ Unstable Diffusion WebUI - Clean Setup
#
# **Compatible with: pip==23.2.1, Python 3.10**

# %%
# STEP 1: Downgrade pip ke versi stabil
# !pip install pip==23.2.1
import os
os.kill(os.getpid(), 9)  # Restart runtime

# %%
# STEP 2: Install dependensi penting
# !pip install -q torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2
# !pip install -q xformers==0.0.20
# !pip install -q git+https://github.com/crowsonkb/k-diffusion.git

# %%
# STEP 3: Clone repo WebUI dan jalankan
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/stable-diffusion-webui
# %cd /content/stable-diffusion-webui

# %%
# STEP 4: Jalankan WebUI
# !COMMANDLINE_ARGS="--share --xformers" python launch.py
